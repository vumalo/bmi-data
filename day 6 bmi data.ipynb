# %% [markdown]
# # A PROJECT ON ANALYSIS OF DATA AND USING REGRESSION MODEL TO PREDICT THE COLUMN "CHARGES"

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:/Users/LALAECO SUPER GLOBAL/Documents/dataInsurance.csv")
df
# Out:
#       age,sex,bmi,children,smoker,region,charges
# 0       19,female,27.9,0,yes,southwest,16884.924
# 1         18,male,33.77,1,no,southeast,1725.5523
# 2             28,male,33,3,no,southeast,4449.462
# 3      33,male,22.705,0,no,northwest,21984.47061
# 4         32,male,28.88,0,no,northwest,3866.8552
# ...                                          ...
# 1333     50,male,30.97,3,no,northwest,10600.5483
# 1334    18,female,31.92,0,no,northeast,2205.9808
# 1335    18,female,36.85,0,no,southeast,1629.8335
# 1336      21,female,25.8,0,no,southwest,2007.945
# 1337  61,female,29.07,0,yes,northwest,29141.3603
#
# [1338 rows x 1 columns]

# %%
df=pd.read_csv("C:/Users/LALAECO SUPER GLOBAL/Documents/dataInsurance.csv", sep='[,]', engine='python')
df
# Out:
#      "age     sex     bmi  children smoker     region      charges"
# 0     "19  female  27.900         0    yes  southwest    16884.924"
# 1     "18    male  33.770         1     no  southeast    1725.5523"
# 2     "28    male  33.000         3     no  southeast     4449.462"
# 3     "33    male  22.705         0     no  northwest  21984.47061"
# 4     "32    male  28.880         0     no  northwest    3866.8552"
# ...   ...     ...     ...       ...    ...        ...           ...
# 1333  "50    male  30.970         3     no  northwest   10600.5483"
# 1334  "18  female  31.920         0     no  northeast    2205.9808"
# 1335  "18  female  36.850         0     no  southeast    1629.8335"
# 1336  "21  female  25.800         0     no  southwest     2007.945"
# 1337  "61  female  29.070         0    yes  northwest   29141.3603"
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['"age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges"'], dtype='object')

# %%
df.isnull().sum()
# Out:
# "age        0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges"    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   "age      1338 non-null   object
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges"  1338 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 73.3+ KB

# %%
dict_data={'"':''}

# %%
df2=df.replace(dict_data, regex=True)
df2
# Out:
#      "age     sex     bmi  children smoker     region     charges"
# 0      19  female  27.900         0    yes  southwest    16884.924
# 1      18    male  33.770         1     no  southeast    1725.5523
# 2      28    male  33.000         3     no  southeast     4449.462
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest    3866.8552
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest   10600.5483
# 1334   18  female  31.920         0     no  northeast    2205.9808
# 1335   18  female  36.850         0     no  southeast    1629.8335
# 1336   21  female  25.800         0     no  southwest     2007.945
# 1337   61  female  29.070         0    yes  northwest   29141.3603
#
# [1338 rows x 7 columns]

# %%
df2.head()
# Out:
#   "age     sex     bmi  children smoker     region     charges"
# 0   19  female  27.900         0    yes  southwest    16884.924
# 1   18    male  33.770         1     no  southeast    1725.5523
# 2   28    male  33.000         3     no  southeast     4449.462
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest    3866.8552

# %%
df2['"age']=pd.to_numeric(df2['"age'])

# %%
df2['charges"']=pd.to_numeric(df2['charges"'])

# %%
df2['bmi']=pd.to_numeric(df2['bmi'])

# %%
df2['children']=pd.to_numeric(df2['children'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   "age      1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges"  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df3=df2.rename({'"age':'age',
                'charges"':'charges'}, axis='columns')

# %%
df3
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#  1.)how many male from the south east has a bmi of 30 and above
# 2.)how many female smokers do we have for the north west
# 3.)how many male smokersz that are older than 25 do we have int the south west

# %% [markdown]
# #  1.)how many male from the south east has a bmi of 30 and above

# %%
df_male=df3[(df3.sex=='male')]
df_male.head()
# Out:
#    age   sex     bmi  children smoker     region      charges
# 1   18  male  33.770         1     no  southeast   1725.55230
# 2   28  male  33.000         3     no  southeast   4449.46200
# 3   33  male  22.705         0     no  northwest  21984.47061
# 4   32  male  28.880         0     no  northwest   3866.85520
# 8   37  male  29.830         2     no  northeast   6406.41070

# %%
df_south=df_male[(df_male.region=='southeast')]
df_south.head()
# Out:
#     age   sex    bmi  children smoker     region     charges
# 1    18  male  33.77         1     no  southeast   1725.5523
# 2    28  male  33.00         3     no  southeast   4449.4620
# 14   27  male  42.13         0    yes  southeast  39611.7577
# 22   18  male  34.10         0     no  southeast   1137.0110
# 42   41  male  21.78         1     no  southeast   6272.4772

# %%
df_bmi=df_south[(df_south.bmi>=30)]
df_bmi
# Out:
#       age   sex    bmi  children smoker     region      charges
# 1      18  male  33.77         1     no  southeast   1725.55230
# 2      28  male  33.00         3     no  southeast   4449.46200
# 14     27  male  42.13         0    yes  southeast  39611.75770
# 22     18  male  34.10         0     no  southeast   1137.01100
# 49     36  male  35.20         1    yes  southeast  38709.17600
# ...   ...   ...    ...       ...    ...        ...          ...
# 1289   44  male  34.32         1     no  southeast   7147.47280
# 1300   45  male  30.36         0    yes  southeast  62592.87309
# 1317   18  male  53.13         0     no  southeast   1163.46270
# 1322   62  male  38.83         0     no  southeast  12981.34570
# 1327   51  male  30.03         1     no  southeast   9377.90470
#
# [140 rows x 7 columns]

# %%
dfplot=df_bmi[['sex','bmi']].head(12)
dfplot
# Out:
#      sex    bmi
# 1   male  33.77
# 2   male  33.00
# 14  male  42.13
# 22  male  34.10
# 49  male  35.20
# 53  male  34.43
# 57  male  31.68
# 61  male  33.66
# 73  male  32.01
# 77  male  35.53
# 82  male  37.62
# 97  male  38.28

# %%
dfplot.plot(y='bmi',x='sex',kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %% [markdown]
# # 2.)how many female smokers do we have for the north west. answer==29

# %%
df_female=df3[(df3.sex=='female')]
df_female.head()
# Out:
#    age     sex    bmi  children smoker     region      charges
# 0   19  female  27.90         0    yes  southwest  16884.92400
# 5   31  female  25.74         0     no  southeast   3756.62160
# 6   46  female  33.44         1     no  southeast   8240.58960
# 7   37  female  27.74         3     no  northwest   7281.50560
# 9   60  female  25.84         0     no  northwest  28923.13692

# %%
df_northwest=df_female[(df_female.region=='northwest')]
df_northwest.head()
# Out:
#     age     sex     bmi  children smoker     region      charges
# 7    37  female  27.740         3     no  northwest   7281.50560
# 9    60  female  25.840         0     no  northwest  28923.13692
# 27   55  female  32.775         2     no  northwest  12268.63225
# 36   62  female  32.965         3     no  northwest  15612.19335
# 47   28  female  34.770         0     no  northwest   3556.92230

# %%
df_smokers=df_northwest[(df_northwest.smoker=='yes')]
df_smokers.shape
# Out:
# (29, 7)

# %%
df_s=df_smokers.groupby('sex')['age'].value_counts()
df_s
# Out:
# sex     age
# female  19     4
#         35     2
#         43     2
#         20     1
#         22     1
#         23     1
#         27     1
#         30     1
#         32     1
#         33     1
#         34     1
#         40     1
#         42     1
#         44     1
#         45     1
#         46     1
#         47     1
#         52     1
#         53     1
#         57     1
#         59     1
#         61     1
#         63     1
#         64     1
# Name: age, dtype: int64

# %% [markdown]
# #  A BAR PLOT OF SEX VS AGE

# %%
df_s.plot(y='age',x='sex',kind='bar',color='red')
# Out:
# <AxesSubplot:xlabel='sex,age'>

# %%
df_smokers[['sex', 'smoker']].head()
# Out:
#         sex smoker
# 64   female    yes
# 86   female    yes
# 128  female    yes
# 160  female    yes
# 375  female    yes

# %% [markdown]
# # 3.)how many male smokers that are older than 25 do we have in the south west. answer==28

# %%
df_male25=df_male[(df_male.region=='southwest')]
df_male25.head()
# Out:
#     age   sex   bmi  children smoker     region    charges
# 12   23  male  34.4         0     no  southwest   1826.843
# 15   19  male  24.6         1     no  southwest   1837.237
# 18   56  male  40.3         0     no  southwest  10602.385
# 19   30  male  35.3         0    yes  southwest  36837.467
# 29   31  male  36.3         2    yes  southwest  38711.000

# %%
df_ms=df_male25[(df_male25.smoker=='yes')&(df_male25.age>25)]
df_ms.head()
# Out:
#     age   sex   bmi  children smoker     region      charges
# 19   30  male  35.3         0    yes  southwest  36837.46700
# 29   31  male  36.3         2    yes  southwest  38711.00000
# 34   28  male  36.4         1    yes  southwest  51194.55914
# 39   60  male  39.9         0    yes  southwest  48173.36100
# 52   48  male  28.0         1    yes  southwest  23568.27200

# %%
df_ms.shape
# Out:
# (28, 7)

# %%
p=df_ms.sort_values(by=['charges'],ascending=False).head(20)
p
# Out:
#       age   sex   bmi  children smoker     region      charges
# 1146   60  male  32.8         0    yes  southwest  52590.82939
# 34     28  male  36.4         1    yes  southwest  51194.55914
# 39     60  male  39.9         0    yes  southwest  48173.36100
# 1284   61  male  36.3         1    yes  southwest  47403.88000
# 739    29  male  35.5         2    yes  southwest  44585.45587
# 271    50  male  34.2         2    yes  southwest  42856.83800
# 621    37  male  34.1         4    yes  southwest  40182.24600
# 682    39  male  35.3         2    yes  southwest  40103.89000
# 1049   49  male  30.9         0    yes  southwest  39727.61400
# 609    30  male  37.8         2    yes  southwest  39241.44200
# 953    44  male  30.2         2    yes  southwest  38998.54600
# 29     31  male  36.3         2    yes  southwest  38711.00000
# 1207   36  male  33.4         2    yes  southwest  38415.47400
# 1303   43  male  27.8         0    yes  southwest  37829.72420
# ...

# %% [markdown]
# #  A BAR PLOT OF AGE VS CHARGES

# %%
p.plot(y='age',x='charges',kind='bar')
# Out:
# <AxesSubplot:xlabel='charges'>

# %% [markdown]
# # 1. which region has the highest number of smokers, and which ages are the highest. answer==southeast, 91

# %%
df_sm=df3[(df3.smoker=='yes')]
df_sm.head()
# Out:
#     age     sex    bmi  children smoker     region     charges
# 0    19  female  27.90         0    yes  southwest  16884.9240
# 11   62  female  26.29         0    yes  southeast  27808.7251
# 14   27    male  42.13         0    yes  southeast  39611.7577
# 19   30    male  35.30         0    yes  southwest  36837.4670
# 23   34  female  31.92         1    yes  northeast  37701.8768

# %%
sw=df_sm[(df_sm.region=='southwest')]
sw.shape
# Out:
# (58, 7)

# %%
se=df_sm[(df_sm.region=='southeast')]
se.shape
# Out:
# (91, 7)

# %%
nw=df_sm[(df_sm.region=='northwest')]
nw.shape
# Out:
# (58, 7)

# %%
ne=df_sm[(df_sm.region=='northeast')]
ne.shape
# Out:
# (67, 7)

# %%
# southeast has the highest number of smokers and ages 60-64 are the highest
se[['age']].sort_values(by=['age'],ascending=False)
# Out:
#       age
# 1265   64
# 1241   64
# 664    64
# 420    64
# 109    63
# ...   ...
# 161    18
# 1204   18
# 57     18
# 759    18
# 803    18
#
# [91 rows x 1 columns]

# %%
# how much does female smokers consume in the northeast. answer==812929.34553
df_femne=df3[(df3.sex=='female')&(df3.smoker=='yes')&(df3.region=='northeast')]
df_femne.head()
# Out:
#      age     sex    bmi  children smoker     region     charges
# 23    34  female  31.92         1    yes  northeast  37701.8768
# 153   42  female  23.37         0    yes  northeast  19964.7463
# 240   23  female  36.67         2    yes  northeast  38511.6283
# 244   63  female  27.74         0    yes  northeast  29523.1656
# 280   40  female  28.12         1    yes  northeast  22331.5668

# %%
df_femne['charges'].sum()
# Out:
# 812929.34553

# %%
# 3. what are the highest age range of smokers in the southwest
df_range=df3[(df3.smoker=='yes')&(df3.region=='southwest')]
df_range.head()
# Out:
#     age     sex   bmi  children smoker     region      charges
# 0    19  female  27.9         0    yes  southwest  16884.92400
# 19   30    male  35.3         0    yes  southwest  36837.46700
# 29   31    male  36.3         2    yes  southwest  38711.00000
# 30   22    male  35.6         0    yes  southwest  35585.57600
# 34   28    male  36.4         1    yes  southwest  51194.55914

# %%
df_range.sort_values(by=['age'], ascending=False).head()
# highest age range of smokers in southwest is 61-64
# Out:
#       age     sex   bmi  children smoker     region    charges
# 328    64  female  33.8         1    yes  southwest  47928.030
# 94     64  female  31.3         2    yes  southwest  47291.055
# 175    63  female  37.7         0    yes  southwest  48824.450
# 251    63  female  32.2         2    yes  southwest  47305.305
# 1284   61    male  36.3         1    yes  southwest  47403.880

# %%
# 4. how much money does male smokers consume in all regions... compare the data
moneysw=df3[(df3.sex=='male')&(df3.smoker=='yes')&(df3.region=='southwest')]
moneysw.head()
# Out:
#     age   sex   bmi  children smoker     region      charges
# 19   30  male  35.3         0    yes  southwest  36837.46700
# 29   31  male  36.3         2    yes  southwest  38711.00000
# 30   22  male  35.6         0    yes  southwest  35585.57600
# 34   28  male  36.4         1    yes  southwest  51194.55914
# 39   60  male  39.9         0    yes  southwest  48173.36100

# %%
moneysw['charges'].sum()
# Out:
# 1206157.9256000002

# %%
moneyse=df3[(df3.sex=='male')&(df3.smoker=='yes')&(df3.region=='southeast')]
moneyse.head()
# Out:
#     age   sex    bmi  children smoker     region     charges
# 14   27  male  42.13         0    yes  southeast  39611.7577
# 49   36  male  35.20         1    yes  southeast  38709.1760
# 53   36  male  34.43         0    yes  southeast  37742.5757
# 57   18  male  31.68         2    yes  southeast  34303.1672
# 69   28  male  23.98         3    yes  southeast  17663.1442

# %%
moneyse['charges'].sum()
# Out:
# 1981641.1651599999

# %%
moneyne=df3[(df3.sex=='male')&(df3.smoker=='yes')&(df3.region=='northeast')]
moneyne.head()
# Out:
#      age   sex     bmi  children smoker     region      charges
# 38    35  male  36.670         1    yes  northeast  39774.27630
# 92    59  male  29.830         3    yes  northeast  30184.93670
# 98    56  male  19.950         0    yes  northeast  22412.64850
# 123   44  male  31.350         1    yes  northeast  39556.49450
# 157   18  male  25.175         0    yes  northeast  15518.18025

# %%
moneyne['charges'].sum()
# Out:
# 1175197.5981500002

# %%
moneynw=df3[(df3.sex=='male')&(df3.smoker=='yes')&(df3.region=='northwest')]
moneynw.head()
# Out:
#      age   sex     bmi  children smoker     region      charges
# 55    58  male  36.955         2    yes  northwest  47496.49445
# 85    45  male  22.895         2    yes  northwest  21098.55405
# 105   20  male  28.025         1    yes  northwest  17560.37975
# 144   30  male  28.690         3    yes  northwest  20745.98910
# 146   46  male  30.495         3    yes  northwest  40720.55105

# %%
moneynw['charges'].sum()
# Out:
# 890682.26116

# %%
# 5. what is the highest age range of male smokers in all the region
q5=df3[(df3.sex=='male')&(df3.smoker=='yes')]
q5.head()
# Out:
#     age   sex    bmi  children smoker     region      charges
# 14   27  male  42.13         0    yes  southeast  39611.75770
# 19   30  male  35.30         0    yes  southwest  36837.46700
# 29   31  male  36.30         2    yes  southwest  38711.00000
# 30   22  male  35.60         0    yes  southwest  35585.57600
# 34   28  male  36.40         1    yes  southwest  51194.55914

# %%
q5.sort_values(by=['age'],ascending=False).head()
# age range for male smokers in all regions 60- 64 years
# Out:
#       age   sex     bmi  children smoker     region      charges
# 1265   64  male  23.760         0    yes  southeast  26926.51440
# 1241   64  male  36.960         2    yes  southeast  49577.66240
# 420    64  male  33.880         0    yes  southeast  46889.26120
# 109    63  male  35.090         0    yes  southeast  47055.53210
# 668    62  male  32.015         0    yes  northeast  45710.20785

# %%
# 6. which region has the highest mean bmi of smokers. answer===southeast
df_bmise=df3[(df3.smoker=='yes')&(df3.region=='southeast')]
df_bmise['bmi'].mean()
# Out:
# 33.09670329670331

# %%
df_bmisw=df3[(df3.smoker=='yes')&(df3.region=='southwest')]
df_bmisw['bmi'].mean()
# Out:
# 31.0051724137931

# %%
df_bmine=df3[(df3.smoker=='yes')&(df3.region=='northeast')]
df_bmine['bmi'].mean()
# Out:
# 28.565223880597017

# %%
df_bminw=df3[(df3.smoker=='yes')&(df3.region=='northwest')]
df_bminw['bmi'].mean()
# Out:
# 29.140431034482756

# %%
# 7. what is the bmi difference smokers in the northwest and that of the southwest
PSE=df3[(df3.smoker=='yes')&(df3.region=='northwest')]
y=PSE['bmi'].sum()
y
# Out:
# 1690.145

# %%
PSW=df3[(df3.smoker=='yes')&(df3.region=='southwest')]
x=PSW['bmi'].sum()
x
# Out:
# 1798.3000000000002

# %%
x-y
# Out:
# 108.1550000000002

# %%
#  8what is the mean bmi of smokers within the range of 25 to 30, compare it to those between 30 - 40
smok=df3[(df3.smoker=='yes')&(df3.age>=25)&(df3.age<=30)]
smok['bmi'].mean()
# Out:
# 29.525428571428566

# %%
smok2=df3[(df3.smoker=='yes')&(df3.age>=30)&(df3.age<=40)]
smok2['bmi'].mean()
# Out:
# 30.27111111111112

# %% [markdown]
# # REGRESSION ANALYSIS
# # USING REGRESSION ANALYSIS TO PREDICT CHARGES

# %%
df3
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
n=df3.columns
n
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
len(n)
# Out:
# 7

# %%
x_col=n[:6]
x_col
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region'], dtype='object')

# %%
x_data=df3[x_col]
x_data
# Out:
#       age     sex     bmi  children smoker     region
# 0      19  female  27.900         0    yes  southwest
# 1      18    male  33.770         1     no  southeast
# 2      28    male  33.000         3     no  southeast
# 3      33    male  22.705         0     no  northwest
# 4      32    male  28.880         0     no  northwest
# ...   ...     ...     ...       ...    ...        ...
# 1333   50    male  30.970         3     no  northwest
# 1334   18  female  31.920         0     no  northeast
# 1335   18  female  36.850         0     no  southeast
# 1336   21  female  25.800         0     no  southwest
# 1337   61  female  29.070         0    yes  northwest
#
# [1338 rows x 6 columns]

# %%
m=df3['charges']
m
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# # Bringing out numeric columns

# %%
h=x_data.select_dtypes(include=np.number)
num=h.columns.to_list()
num
# Out:
# ['age', 'bmi', 'children']

# %% [markdown]
# # Bringing out non_numeric columns

# %%
j=x_data.select_dtypes(include=np.object)
nonum=j.columns.to_list()
nonum
# Out:
# <ipython-input-71-b60891459ffc>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   j=x_data.select_dtypes(include=np.object)
# ['sex', 'smoker', 'region']

# %%
numeric=x_data[num]
numeric
# Out:
#       age     bmi  children
# 0      19  27.900         0
# 1      18  33.770         1
# 2      28  33.000         3
# 3      33  22.705         0
# 4      32  28.880         0
# ...   ...     ...       ...
# 1333   50  30.970         3
# 1334   18  31.920         0
# 1335   18  36.850         0
# 1336   21  25.800         0
# 1337   61  29.070         0
#
# [1338 rows x 3 columns]

# %%
non_numeric=x_data[nonum]
non_numeric
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
from sklearn import preprocessing

# %% [markdown]
# # Converting/encoding non-numeric columns to numeric

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
pn=non_numeric.columns

# %%
for i in pn:
    non_numeric[i]=label_encoder.fit_transform(non_numeric[i])
# Out:
# <ipython-input-77-b5fb1462b742>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_numeric[i]=label_encoder.fit_transform(non_numeric[i])

# %%
non_numeric
# Out:
#       sex  smoker  region
# 0       0       1       3
# 1       1       0       2
# 2       1       0       2
# 3       1       0       1
# 4       1       0       1
# ...   ...     ...     ...
# 1333    1       0       1
# 1334    0       0       0
# 1335    0       0       2
# 1336    0       0       3
# 1337    0       1       1
#
# [1338 rows x 3 columns]

# %%
concat_data=pd.concat([numeric,non_numeric],axis=1)
concat_data
# Out:
#       age     bmi  children  sex  smoker  region
# 0      19  27.900         0    0       1       3
# 1      18  33.770         1    1       0       2
# 2      28  33.000         3    1       0       2
# 3      33  22.705         0    1       0       1
# 4      32  28.880         0    1       0       1
# ...   ...     ...       ...  ...     ...     ...
# 1333   50  30.970         3    1       0       1
# 1334   18  31.920         0    0       0       0
# 1335   18  36.850         0    0       0       2
# 1336   21  25.800         0    0       0       3
# 1337   61  29.070         0    0       1       1
#
# [1338 rows x 6 columns]

# %%
concat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   bmi       1338 non-null   float64
#  2   children  1338 non-null   int64
#  3   sex       1338 non-null   int32
#  4   smoker    1338 non-null   int32
#  5   region    1338 non-null   int32
# dtypes: float64(1), int32(3), int64(2)
# memory usage: 47.2 KB

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(concat_data, m ,test_size=0.29, random_state=4)
X_train.head()
# Out:
#       age     bmi  children  sex  smoker  region
# 59     34  37.335         2    0       0       1
# 793    53  20.900         0    1       1       2
# 328    64  33.800         1    0       1       3
# 895    61  44.000         0    0       0       3
# 1184   23  28.490         1    0       1       2

# %%
X_train.shape
# Out:
# (949, 6)

# %%
X_test.shape
# Out:
# (389, 6)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
linear=lr.fit(X_train,y_train)
linear
# Out:
# LinearRegression()

# %%
from sklearn import metrics
met=lr.score(X_train,y_train)
met
# Out:
# 0.7650192409991283

# %%
X_train.columns
# Out:
# Index(['age', 'bmi', 'children', 'sex', 'smoker', 'region'], dtype='object')

# %%
pred=[]
for i in range(0,len(X_train.columns)):
    value=float(input('enter a new number:'))
    pred.append(value)
print(pred)
# Out:
# enter a new number:34
# enter a new number:33.3
# enter a new number:2
# enter a new number:0
# enter a new number:0
# enter a new number:1
# [34.0, 33.3, 2.0, 0.0, 0.0, 1.0]

# %%
prd=linear.predict([pred])
print(prd)
# Out:
# [8616.25032579]

# %% [markdown]
# #  predicting smoker based on classification

# %%
o=df3['smoker']
o
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
df3
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
new_data=df3.drop(['smoker'],axis=1)
new_data
# Out:
#       age     sex     bmi  children     region      charges
# 0      19  female  27.900         0  southwest  16884.92400
# 1      18    male  33.770         1  southeast   1725.55230
# 2      28    male  33.000         3  southeast   4449.46200
# 3      33    male  22.705         0  northwest  21984.47061
# 4      32    male  28.880         0  northwest   3866.85520
# ...   ...     ...     ...       ...        ...          ...
# 1333   50    male  30.970         3  northwest  10600.54830
# 1334   18  female  31.920         0  northeast   2205.98080
# 1335   18  female  36.850         0  southeast   1629.83350
# 1336   21  female  25.800         0  southwest   2007.94500
# 1337   61  female  29.070         0  northwest  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# # Getting numeric data columns

# %%
rt=new_data.select_dtypes(include=np.number)
numbers=rt.columns.to_list()
numbers
# Out:
# ['age', 'bmi', 'children', 'charges']

# %% [markdown]
# # Getting non_numeric data columns

# %%
pt=new_data.select_dtypes(include=np.object)
objects=pt.columns.to_list()
objects
# Out:
# <ipython-input-116-4a5dd5d59715>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pt=new_data.select_dtypes(include=np.object)
# ['sex', 'region']

# %%
digits=new_data[numbers]
digits
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1338 rows x 4 columns]

# %%
letters=new_data[objects]
letters
# Out:
#          sex     region
# 0     female  southwest
# 1       male  southeast
# 2       male  southeast
# 3       male  northwest
# 4       male  northwest
# ...      ...        ...
# 1333    male  northwest
# 1334  female  northeast
# 1335  female  southeast
# 1336  female  southwest
# 1337  female  northwest
#
# [1338 rows x 2 columns]

# %%
obj=letters.columns
obj
# Out:
# Index(['sex', 'region'], dtype='object')

# %% [markdown]
# # Converting/encoding non-numeric to numeric values

# %%
for i in obj:
    letters[i]=label_encoder.fit_transform(letters[i])
# Out:
# <ipython-input-120-cdfbd1605d4f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   letters[i]=label_encoder.fit_transform(letters[i])

# %%
letters
# Out:
#       sex  region
# 0       0       3
# 1       1       2
# 2       1       2
# 3       1       1
# 4       1       1
# ...   ...     ...
# 1333    1       1
# 1334    0       0
# 1335    0       2
# 1336    0       3
# 1337    0       1
#
# [1338 rows x 2 columns]

# %%
conc_val=pd.concat([digits,letters],axis=1)
conc_val
# Out:
#       age     bmi  children      charges  sex  region
# 0      19  27.900         0  16884.92400    0       3
# 1      18  33.770         1   1725.55230    1       2
# 2      28  33.000         3   4449.46200    1       2
# 3      33  22.705         0  21984.47061    1       1
# 4      32  28.880         0   3866.85520    1       1
# ...   ...     ...       ...          ...  ...     ...
# 1333   50  30.970         3  10600.54830    1       1
# 1334   18  31.920         0   2205.98080    0       0
# 1335   18  36.850         0   1629.83350    0       2
# 1336   21  25.800         0   2007.94500    0       3
# 1337   61  29.070         0  29141.36030    0       1
#
# [1338 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test=train_test_split(conc_val, o, test_size=0.29, random_state=4)
X_train.head()
# Out:
#       age     bmi  children      charges  sex  region
# 59     34  37.335         2   5989.52365    0       1
# 793    53  20.900         0  21195.81800    1       2
# 328    64  33.800         1  47928.03000    0       3
# 895    61  44.000         0  13063.88300    0       3
# 1184   23  28.490         1  18328.23810    0       2

# %%
X_train.shape
# Out:
# (949, 6)

# %%
X_test.shape
# Out:
# (389, 6)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
stax=DecisionTreeClassifier()
stax
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Fitting decision classifier in X_train, y_train

# %%
stax_fit=stax.fit(X_train,y_train)
stax_fit
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # using decision classifier to score X_train, y_train(X_test, y_test)

# %%
from sklearn import metrics
sta=stax.score(X_train,y_train)
sta
# Out:
# 1.0

# %%
X_train.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex', 'region'], dtype='object')

# %%
val_pred=[]
for i in X_train.columns:
    valu=float(input('enter a num:'))
    val_pred.append(valu)
print(val_pred)
# Out:
# enter a num:34
# enter a num:33
# enter a num:2
# enter a num:0
# enter a num:0
# enter a num:1
# [34.0, 33.0, 2.0, 0.0, 0.0, 1.0]

# %%
pred_smoker=stax_fit.predict([val_pred])
pred_smoker
# Out:
# array(['no'], dtype=object)
